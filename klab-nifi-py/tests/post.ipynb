# %%
import requests

url = "http://localhost:3306"

payload = {
    "collectionId": "abcd",
    "featureCount": 5,
    "dtURL": "https://services.integratedmodelling.org/runtime/main/api/v1/dt/ESA_INSTITUTIONAL.1wvn4m25juf",
    "parquetDownloadUrl": "https://iiasa.blob.core.windows.net/storage/Europev2/Europev2.parquet"
}

response = requests.post(url, json=payload)

print(response.status_code)
# Out:
# 200
